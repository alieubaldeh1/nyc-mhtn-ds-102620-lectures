# %% [markdown]
# # JSON and APIs
#
# _November 3, 2020_
#
# Agenda today:
# - Introduction to API and Remote Server Model
# - Getting data through an API: Case study with YELP API

# %%
import sqlite3
import pandas as pd
import numpy as np
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# ## Part I. APIs and Remote Server Model
# API stands for Application Programming Interface. At some point or the other, large companies would build API for their products for their clients or internal use. It allows the company's application to communicate with another application. But what _exactly_ is an API?
#
# #### Remote server
# When we think about the world of Web, we can think of it as a collection of _servers_. And servers are nothing but huge computers that store a huge amount of data from users and are optimized to process requests. For example, when you type in www.facebook.com, your browser sends a _request_ to the Facebook server, and gets a response from the server, thus interpreting the code and displaying your homepage.
#
# In this case, your browser is the _client_, and Facebook’s server is an API. To put it broadly, whenever you visit a website, you are interacting with its API. However, an API isn’t the same as the remote server — rather it is the part of the server that receives __requests__ and sends __responses__.
#
# <img src='status-code.png' width = 500>

# %% [markdown]
# ## Part II. Getting Data Through APIs
#
# The `get()` method send a request to YELP's API, and stored information in a variable called `request`. Next, let's see if it's successful.

# %% [markdown]
# #### YELP API
# Sometimes you need _authentication_ to get data from a service in additional to just sending a `GET()` request. Yelp API is a perfect example.
#
# You will need to go to the YELP's developer's [website](https://www.yelp.com/developers/v3/manage_app) and request for a client ID and API key, which function like a key into a house of data.
#
# <img src='yelp.png' width = 500>

# %%
# lets try to get some data from yelp!
url = 'https://api.yelp.com/v3/businesses/search'
response = requests.get(url)

# %%
# check the status code
response.status_code

# what happened here?
# Out:
# 400

# %%
# now we are ready to get our data 

# usually, services would limit you to a certain amount of API calls. This varies from service
# to service, so you have to watch out to it 

MY_API_KEY = "K5Tf1q8zd_WxP33QLuYUUUUQVH0Y9oMzazd55AD7sbDpcWuJ2ZRtywRWBcU0QASrt9y-TQ7Ds8AqqMDPFbMqbauh6knSftNgqNRSC-8ilkyYZynrG3CyvBxdKaOhX3Yx"


term = 'African Food'
location = 'Brooklyn'
SEARCH_LIMIT = 30

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(MY_API_KEY),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
# MY_API_KEY = "K5Tf1q8zd_WxP33QLuYUUUUQVH0Y9oMzazd55AD7sbDpcWuJ2ZRtywRWBcU0QASrt9y-TQ7Ds8AqqMDPFbMqbauh6knSftNgqNRSC-8ilkyYZynrG3CyvBxdKaOhX3Yx"

# term2 = 'African food'
# location2 = 'Brooklyn'
# SEARCH_LIMIT2 = 30

# url2 = 'https://api.yelp.com/v3/businesses/search'

# headers2 = {
#         'Authorization': 'Bearer {}'.format(MY_API_KEY),
#     }

# url_params2 = {
#                 'term2': term2.replace(' ', '+'),
#                 'location2': location2,
#                 'limit2': SEARCH_LIMIT2
#             }
# response2 = requests.get(url2, headers=headers2, params=url_params2)

# %%
response.status_code
# Out:
# 200

# %%
# examine the response object

#print(response2)

# %%
# how are we going to parse the response.text object?

response.text
# Out:
# '{"businesses": [{"id": "roT-M9epcHDOGjYgGmWpoA", "alias": "ras-plant-based-brooklyn", "name": "Ras Plant Based", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/MjF2oeWNHPQKrpYt3lLwVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ras-plant-based-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg", "review_count": 71, "categories": [{"alias": "ethiopian", "title": "Ethiopian"}, {"alias": "vegan", "title": "Vegan"}], "rating": 5.0, "coordinates": {"latitude": 40.67341, "longitude": -73.956712}, "transactions": ["delivery", "pickup"], "location": {"address1": "739 Franklin Ave", "address2": "", "address3": null, "city": "Brooklyn", "zip_code": "11238", "country": "US", "state": "NY", "display_address": ["739 Franklin Ave", "Brooklyn, NY 11238"]}, "phone": "+17186226220", "display_phone": "(718) 622-6220", "distance": 2761.0099534890937}, {"id": "NPmqKZzKxwEXCZQZL7viHA", "alias": "ghenet-brooklyn-brooklyn", "name": "Ghenet Brooklyn", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vKP2seg2qOv7it0uwjPkPw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ghenet-brooklyn-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg", "review_count": 496, "categories": [{"alias": "ethiopian", "title": "Ethiopian"}, {"alias": "african", "title": "African"}], "rating": 4.0, "coordinates": {"latitude": 40.6791399, "longitude": -73.98153}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "348 Douglass St", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["348 Douglass St", "Brooklyn, NY 11217"]}, "phone": "+17182304475", "display_phone": "(718) 230-4475", "distance": 4640.694289632243}, {"id": "ECk9dN7IVQvueTCoGO6gCA", "alias": "akwaaba-restaurant-brooklyn", "name": "AKWAABA RESTAURANT", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/U0cqXbmQqr2M6qigiW-U7Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/akwaaba-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg", "review_count": 16, "categories": [{"alias": "african", "title": "African"}], "rating": 4.5, "coordinates": {"latitude": 40.655952, "longitude": -73.953308}, "transactions": [], "price": "$$", "location": {"address1": "604 Parkside Ave", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11226", "country": "US", "state": "NY", "display_address": ["604 Parkside Ave", "Brooklyn, NY 11226"]}, "phone": "+13479852588", "display_phone": "(347) 985-2588", "distance": 1248.9487012131453}, {"id": "Bo1eW6NCzOMuxIyu6CzutQ", "alias": "brooklyn-suya-brooklyn-2", "name": "Brooklyn Suya", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/MK7bCtJjtzId-YREx-7w_A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/brooklyn-suya-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg", "review_count": 65, "categories": [{"alias": "african", "title": "African"}, {"alias": "hotdogs", "title": "Fast Food"}], "rating": 4.5, "coordinates": {"latitude": 40.67402, "longitude": -73.95661}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "717 Franklin Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11216", "country": "US", "state": "NY", "display_address": ["717 Franklin Ave", "Brooklyn, NY 11216"]}, "phone": "+17185130122", "display_phone": "(718) 513-0122", "distance": 2815.1447681204186}, {"id": "FdB6KDTEmX8HvomPwySAHg", "alias": "joloff-restaurant-brooklyn", "name": "Joloff Restaurant", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/n9NXWl4uPcRjbtJC1_psKg/o.jpg", "is_closed": false, "url": "https://ww ...

# %%
# json.load()

#json.loads()

type(json.loads(response.text))
# Out:
# dict

# %%
# working with JSON

african_food = response.text
african_food = json.loads(african_food)

# %%
african_food
# Out:
# {'businesses': [{'id': 'roT-M9epcHDOGjYgGmWpoA',
#    'alias': 'ras-plant-based-brooklyn',
#    'name': 'Ras Plant Based',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MjF2oeWNHPQKrpYt3lLwVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ras-plant-based-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 71,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67341, 'longitude': -73.956712},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '739 Franklin Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['739 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186226220',
#    'display_phone': '(718) 622-6220',
#    'distance': 2761.0099534890937},
#   {'id': 'NPmqKZzKxwEXCZQZL7viHA',
#    'alias': 'ghenet-brooklyn-brooklyn',
#    'name': 'Ghenet Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vKP2seg2qOv7it0uwjPkPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ghenet-brooklyn-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 496,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6791399, 'longitude': -73.98153},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '348 Douglass St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['348 Douglass St', 'Brooklyn, NY 11217']},
#    'phone': '+17182304475',
#    'display_phone': '(718) 230-4475',
#    'distance': 4640.694289632243},
#   {'id': 'ECk9dN7IVQvueTCoGO6gCA',
#    'alias': 'akwaaba-restaurant-brooklyn',
#    'name': 'AKWAABA RESTAURANT',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U0cqXbmQqr2M6qigiW-U7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/akwaaba-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 16,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.655952, 'longitude': -73.953308},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '604 Parkside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['604 Parkside Ave', 'Brooklyn, NY 11226']},
#    'phone': '+13479852588',
#    'display_phone': '(347) 985-2588',
#    'distance': 1248.9487012131453},
#   {'id': 'Bo1eW6NCzOMuxIyu6CzutQ',
#    'alias': 'brooklyn-suya-brooklyn-2',
#    'name': 'Brooklyn Suya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MK7bCtJjtzId-YREx-7w_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-suya-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 65,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67402, 'longitude': -73.95661},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '717 Franklin Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['717 Franklin Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17185130122',
#    'display_phone': '(718) 513-0122',
#    'distance': 2815.1447681204186},
#   {'id': 'FdB6KDTEmX8HvomPwySAHg',
#    'alias': 'joloff-restaurant-brooklyn',
#    'name': 'Joloff Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n9NXWl4uPcRjbtJC1_psKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joloff-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 191,
#    'categories': [{'alias': 'senegalese', 'title': 'Senegalese'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6841, 'longitude': -73.95422},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1168 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1168 Bedford Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17182300523',
#    'display_phone': '(718) 230-0523',
#    'distance': 3755.8933994011004},
#   {'id': 'l4fwf8VwAokv3MWT45Ab7g',
#    'alias': 'bunna-cafe-brooklyn',
#    'name': 'Bunna Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jGKIcCZ2lx23kKX2YRug7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunna-cafe-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 629,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.705042, 'longitude': -73.928078},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1084 Flushing Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1084 Flushing Ave', 'Brooklyn, NY 11237']},
#    'phone': '+13472952227',
#    'display_phone': '(347) 295-2227',
#    'distance': 5938.015892656367},
#   {'id': 'YJ05uT-i4-pTUB_y1an6zw',
#    'alias': 'awash-brooklyn-brooklyn-5',
#    'name': 'Awash Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e_16iI66wCBiTs8_iiueIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awash-brooklyn-brooklyn-5?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 190,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6858, 'longitude': -73.99441},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '242 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17182432151',
#    'display_phone': '(718) 243-2151',
#    'distance': 5957.100687417107},
#   {'id': 'r_QEUVdoo8dsKR9fK31w3w',
#    'alias': 'paradis-des-gouts-brooklyn',
#    'name': 'Paradis Des Gouts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AD-VB6dzNNXuh4sUYCq4mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paradis-des-gouts-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 53,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69333, 'longitude': -73.92931},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1136 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1136 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+17184434584',
#    'display_phone': '(718) 443-4584',
#    'distance': 4645.028871114836},
#   {'id': 'Ra7TDn3poDX1RGMKMKTcBA',
#    'alias': 'hills-kitchen-brooklyn-2',
#    'name': 'Hills Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sEbUu_tw0jJAVyjYcBAd9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hills-kitchen-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 22,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70253, 'longitude': -73.92513},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '252 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+19294808775',
#    'display_phone': '(929) 480-8775',
#    'distance': 5700.697831746331},
#   {'id': 'wSr-7T0yep69hlqCGFuTSA',
#    'alias': 'festac-grill-brooklyn',
#    'name': 'Festac Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p0x8tbwHp1p6CNFmh_K6tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/festac-grill-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 24,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6757317, 'longitude': -73.8899689},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '263 Hendrix St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['263 Hendrix St', 'Brooklyn, NY 11207']},
#    'phone': '+13476275151',
#    'display_phone': '(347) 627-5151',
#    'distance': 4908.4399539324395},
#   {'id': 'dqvNBLqqwgA3iZfRn-Kb6w',
#    'alias': 'the-green-place-nigeria-restaurant-brooklyn',
#    'name': 'The Green Place Nigeria Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lc6BOQjQH0km11_Rn6kHDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-green-place-nigeria-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 30,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677021, 'longitude': -73.911163},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Rockaway Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Rockaway Ave', 'Brooklyn, NY 11233']},
#    'phone': '+13477852738',
#    'display_phone': '(347) 785-2738',
#    'distance': 3634.22075830529},
#   {'id': '_sipbeIM-EtR4cIzleEUhg',
#    'alias': 'cafe-rue-dix-brooklyn',
#    'name': 'Cafe Rue Dix',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PdETQUixQGCe54eXuv3iMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rue-dix-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 366,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'senegalese', 'title': 'Senegalese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6740232907878,
#     'longitude': -73.9538387930572},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1451 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1451 Bedford Ave', 'Brooklyn, NY 11216']},
#    'phone': '+19292342543',
#    'display_phone': '(929) 234-2543',
#    'distance': 2703.6373554528677},
#   {'id': 'cWzdIJhEDZIjSGDpYGWy3Q',
#    'alias': 'buka-new-york-brooklyn',
#    'name': 'Buka New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IBO_rn4OqQwLfjyJCsSEcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buka-new-york-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 253,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'african', 'title': 'African'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.68242, 'longitude': -73.96301},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '946 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['946 Fulton St', 'Brooklyn, NY 11238']},
#    'phone': '+13477630619',
#    'display_phone': '(347) 763-0619',
#    'distance': 3884.018898308043},
#   {'id': 'Rb0wYM83GifC-P1Rqd23Bg',
#    'alias': 'hadja-marley-brooklyn',
#    'name': 'Hadja Marley',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GU0X9nr7DBZPThLqGzDyAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hadja-marley-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 7,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68147, 'longitude': -73.95611},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1139 Fulton St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1139 Fulton St', 'Brooklyn, NY 11238']},
#    'phone': '+17186367422',
#    'display_phone': '(718) 636-7422',
#    'distance': 3532.876270195536},
#   {'id': 'TeOmHHAIMgK4X7BnvA_BmQ',
#    'alias': 'adebola-african-restaurant-woodbridge-township-2',
#    'name': 'Adebola African Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/roZPq28jU46mLMz1vRxIIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adebola-african-restaurant-woodbridge-township-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 1,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.55499, 'longitude': -74.30152},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '197 Woodbridge Center Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodbridge Township',
#     'zip_code': '07095',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['197 Woodbridge Center Dr',
#      'Woodbridge Township, NJ 07095']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 32145.33845656266},
#   {'id': '4wyPdXX96e0akxvCp268iw',
#    'alias': 'accra-restaurant-new-york',
#    'name': 'Accra Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ffrwe76XkIl-lehuQ-Bvcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/accra-restaurant-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 129,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8079504, 'longitude': -73.9490877},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2065 Adam Clayton Powell Jr Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2065 Adam Clayton Powell Jr Blvd',
#      'New York, NY 10027']},
#    'phone': '+12129327739',
#    'display_phone': '(212) 932-7739',
#    'distance': 17323.55977177803},
#   {'id': 'GjAHO7PA-3Sxg1lkGza4sQ',
#    'alias': 'b-and-b-restaurant-corporation-new-york',
#    'name': 'B&B Restaurant Corporation',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1K16MSCu2unC9HVUqnhDBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-b-restaurant-corporation-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 147,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7459112, 'longitude': -73.9936086},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '165 West 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 West 26th St', 'New York, NY 10001']},
#    'phone': '+16464298174',
#    'display_phone': '(646) 429-8174',
#    'distance': 11366.289311741328},
#   {'id': 'lAwfazjM5ot64O4A6EAjjQ',
#    'alias': 'le-succulent-brooklyn-2',
#    'name': 'Le Succulent',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4StjLv6AF0ASwJnPJFh_iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-succulent-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 89,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67356, 'longitude': -73.98247},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '291 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['291 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13472278282',
#    'display_phone': '(347) 227-8282',
#    'distance': 4322.981625564775},
#   {'id': 'ibxhUQF1m70ymB9lMFG5og',
#    'alias': 'bati-brooklyn-2',
#    'name': 'Bati',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MnghD_waFAxqH9x04019mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bati-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 222,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6865076, 'longitude': -73.9746607},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '747 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['747 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+17187979696',
#    'display_phone': '(718) 797-9696',
#    'distance': 4844.406635045685},
#   {'id': 'lXPQ5iNQjEPxX86D8YLV-w',
#    'alias': 'amarachi-brooklyn-2',
#    'name': 'Amarachi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V75vInDaQVfO8Iu2W6HIMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amarachi-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 371,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69803, 'longitude': -73.98482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '189 Bridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Bridge St', 'Brooklyn, NY 11201']},
#    'phone': '+17182221010',
#    'display_phone': '(718) 222-1010',
#    'distance': 6352.922776445601},
#   {'id': 'uwj3FOQ0ucGOxk3vBXaBCg',
#    'alias': 'teranga-new-york-2',
#    'name': 'Teranga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hdirer4OT44hO9NmG8V4Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teranga-new-york-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 74,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.796278, 'longitude': -73.949119},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1280 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1280 5th Ave', 'New York, NY 10029']},
#    'phone': '+16466631935',
#    'display_phone': '(646) 663-1935',
#    'distance': 16017.41850672178},
#   {'id': 'pwarWuPn7Aw_il-epzJEgg',
#    'alias': 'awash-ethiopian-restaurant-new-york-3',
#    'name': 'Awash Ethiopian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MTJUXz_vjrh7-qaKIXzyxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awash-ethiopian-restaurant-new-york-3?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 332,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72658, 'longitude': -73.98682},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '338 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['338 E 6th St', 'New York, NY 10003']},
#    'phone': '+12129829589',
#    'display_phone': '(212) 982-9589',
#    'distance': 9173.860629261962},
#   {'id': 'kXnTlyTQ9foQ6KOvn7SYbQ',
#    'alias': 'africana-restaurant-jamaica',
#    'name': 'Africana Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7J97ujxHc8WJoFbIA6tZIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/africana-restaurant-jamaica?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 10,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6948099, 'longitude': -73.80568},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146-12 Liberty Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jamaica',
#     'zip_code': '11435',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146-12 Liberty Ave', 'Jamaica, NY 11435']},
#    'phone': '+17186588501',
#    'display_phone': '(718) 658-8501',
#    'distance': 12220.664784429222},
#   {'id': '10jVTXpBuF17HfeALDF_NQ',
#    'alias': 'monas-cuisine-staten-island',
#    'name': 'Monas Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hLDzFu7bg6BKT-PXRinytA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monas-cuisine-staten-island?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 8,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6184136034919,
#     'longitude': -74.0850521349529},
#    'transactions': [],
#    'location': {'address1': '360 Targee St',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['360 Targee St', 'Staten Island, NY 10304']},
#    'phone': '+13478253352',
#    'display_phone': '(347) 825-3352',
#    'distance': 12859.17113506546},
#   {'id': 'qg0pk5UG638g4CRLvbiq7Q',
#    'alias': 'le-baobab-gouygui-2-brooklyn',
#    'name': 'Le Baobab Gouygui 2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vWgPm5vEvsy9omgbk_zT5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-baobab-gouygui-2-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 30,
#    'categories': [{'alias': 'senegalese', 'title': 'Senegalese'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68077, 'longitude': -73.95211},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1235 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1235 Fulton St', 'Brooklyn, NY 11216']},
#    'phone': '+17184844866',
#    'display_phone': '(718) 484-4866',
#    'distance': 3330.2240312398685},
#   {'id': '2tTUnW5filzR3YG-G7rZ0w',
#    'alias': 'benyam-cuisine-new-york',
#    'name': 'Benyam Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B1knNZx_nR5aG1scxAUdZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benyam-cuisine-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 127,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.82522, 'longitude': -73.94058},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2795 Frederick Douglas Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10039',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2795 Frederick Douglas Blvd', 'New York, NY 10039']},
#    'phone': '+12125107353',
#    'display_phone': '(212) 510-7353',
#    'distance': 19222.462927128287},
#   {'id': 'RC58AacE9s8VMMCz0boE4A',
#    'alias': 'berber-street-food-new-york-2',
#    'name': 'Berber Street Food',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3nEC_E4E3ICRRgSSaiJu4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berber-street-food-new-york-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 47,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7302376195336,
#     'longitude': -74.0033399462744},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '35 Carmine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Carmine St', 'New York, NY 10014']},
#    'phone': '+16468700495',
#    'display_phone': '(646) 870-0495',
#    'distance': 10205.021486575273},
#   {'id': 'C2E1E0o-ssSrf_dokwxTXg',
#    'alias': 'massawa-new-york',
#    'name': 'Massawa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xfrp9C-QkcKfBrUoBbxbwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/massawa-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 297,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'african', 'title': 'African'},
#     {'alias': 'eritrean', 'title': 'Eritrean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8099, 'longitude': -73.95856},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1239 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1239 Amsterdam Ave', 'New York, NY 10027']},
#    'phone': '+12126630505',
#    'display_phone': '(212) 663-0505',
#    'distance': 17582.909342154006},
#   {'id': 'sfF432UjmaMdxBQDigUENw',
#    'alias': 'olaides-kitchen-parlin',
#    'name': "Olaide's Kitchen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uHn8Z5EqQBslc3BPjsMrLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olaides-kitchen-parlin?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 31,
#    'categories': [{'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.4545282409871,
#     'longitude': -74.2946314679703},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '499 Ernston Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Parlin',
#     'zip_code': '08859',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['499 Ernston Rd', 'Parlin, NJ 08859']},
#    'phone': '+17329528880',
#    'display_phone': '(732) 952-8880',
#    'distance': 37211.18231292543},
#   {'id': 'r271Tv2uqJtIcghCFRa8BQ',
#    'alias': 'haile-bistro-new-york',
#    'name': 'Haile Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dkqvQWWa6moYhJvg0BwNeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haile-bistro-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#    'review_count': 219,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72783, 'longitude': -73.97951},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '182 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['182 Ave B', 'New York, NY 10009']},
#    'phone': '+12126738949',
#    'display_phone': '(212) 673-8949',
#    'distance': 9046.199724119593}],
#  'total': 103,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %%
# cleaning and exploring the data
for key in african_food.keys():
    print(key)
# Out:
# businesses
# total
# region

# %%
african_food['total']
# Out:
# 103

# %%
african_food['region']
# Out:
# {'center': {'longitude': -73.93936157226562, 'latitude': 40.652330148320374}}

# %%
african_food['businesses']
# Out:
# [{'id': 'roT-M9epcHDOGjYgGmWpoA',
#   'alias': 'ras-plant-based-brooklyn',
#   'name': 'Ras Plant Based',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MjF2oeWNHPQKrpYt3lLwVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ras-plant-based-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 71,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.67341, 'longitude': -73.956712},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '739 Franklin Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['739 Franklin Ave', 'Brooklyn, NY 11238']},
#   'phone': '+17186226220',
#   'display_phone': '(718) 622-6220',
#   'distance': 2761.0099534890937},
#  {'id': 'NPmqKZzKxwEXCZQZL7viHA',
#   'alias': 'ghenet-brooklyn-brooklyn',
#   'name': 'Ghenet Brooklyn',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vKP2seg2qOv7it0uwjPkPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ghenet-brooklyn-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 496,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6791399, 'longitude': -73.98153},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '348 Douglass St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['348 Douglass St', 'Brooklyn, NY 11217']},
#   'phone': '+17182304475',
#   'display_phone': '(718) 230-4475',
#   'distance': 4640.694289632243},
#  {'id': 'ECk9dN7IVQvueTCoGO6gCA',
#   'alias': 'akwaaba-restaurant-brooklyn',
#   'name': 'AKWAABA RESTAURANT',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U0cqXbmQqr2M6qigiW-U7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/akwaaba-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 16,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.655952, 'longitude': -73.953308},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '604 Parkside Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11226',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['604 Parkside Ave', 'Brooklyn, NY 11226']},
#   'phone': '+13479852588',
#   'display_phone': '(347) 985-2588',
#   'distance': 1248.9487012131453},
#  {'id': 'Bo1eW6NCzOMuxIyu6CzutQ',
#   'alias': 'brooklyn-suya-brooklyn-2',
#   'name': 'Brooklyn Suya',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MK7bCtJjtzId-YREx-7w_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyn-suya-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 65,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.67402, 'longitude': -73.95661},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '717 Franklin Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['717 Franklin Ave', 'Brooklyn, NY 11216']},
#   'phone': '+17185130122',
#   'display_phone': '(718) 513-0122',
#   'distance': 2815.1447681204186},
#  {'id': 'FdB6KDTEmX8HvomPwySAHg',
#   'alias': 'joloff-restaurant-brooklyn',
#   'name': 'Joloff Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n9NXWl4uPcRjbtJC1_psKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joloff-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 191,
#   'categories': [{'alias': 'senegalese', 'title': 'Senegalese'},
#    {'alias': 'halal', 'title': 'Halal'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6841, 'longitude': -73.95422},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1168 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1168 Bedford Ave', 'Brooklyn, NY 11216']},
#   'phone': '+17182300523',
#   'display_phone': '(718) 230-0523',
#   'distance': 3755.8933994011004},
#  {'id': 'l4fwf8VwAokv3MWT45Ab7g',
#   'alias': 'bunna-cafe-brooklyn',
#   'name': 'Bunna Cafe',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jGKIcCZ2lx23kKX2YRug7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bunna-cafe-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 629,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.705042, 'longitude': -73.928078},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1084 Flushing Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1084 Flushing Ave', 'Brooklyn, NY 11237']},
#   'phone': '+13472952227',
#   'display_phone': '(347) 295-2227',
#   'distance': 5938.015892656367},
#  {'id': 'YJ05uT-i4-pTUB_y1an6zw',
#   'alias': 'awash-brooklyn-brooklyn-5',
#   'name': 'Awash Brooklyn',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e_16iI66wCBiTs8_iiueIA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/awash-brooklyn-brooklyn-5?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 190,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6858, 'longitude': -73.99441},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '242 Court St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['242 Court St', 'Brooklyn, NY 11201']},
#   'phone': '+17182432151',
#   'display_phone': '(718) 243-2151',
#   'distance': 5957.100687417107},
#  {'id': 'r_QEUVdoo8dsKR9fK31w3w',
#   'alias': 'paradis-des-gouts-brooklyn',
#   'name': 'Paradis Des Gouts',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AD-VB6dzNNXuh4sUYCq4mw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paradis-des-gouts-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 53,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'french', 'title': 'French'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69333, 'longitude': -73.92931},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1136 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1136 Broadway', 'Brooklyn, NY 11221']},
#   'phone': '+17184434584',
#   'display_phone': '(718) 443-4584',
#   'distance': 4645.028871114836},
#  {'id': 'Ra7TDn3poDX1RGMKMKTcBA',
#   'alias': 'hills-kitchen-brooklyn-2',
#   'name': 'Hills Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sEbUu_tw0jJAVyjYcBAd9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hills-kitchen-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 22,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70253, 'longitude': -73.92513},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '252 Knickerbocker Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['252 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+19294808775',
#   'display_phone': '(929) 480-8775',
#   'distance': 5700.697831746331},
#  {'id': 'wSr-7T0yep69hlqCGFuTSA',
#   'alias': 'festac-grill-brooklyn',
#   'name': 'Festac Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p0x8tbwHp1p6CNFmh_K6tQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/festac-grill-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 24,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6757317, 'longitude': -73.8899689},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '263 Hendrix St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11207',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['263 Hendrix St', 'Brooklyn, NY 11207']},
#   'phone': '+13476275151',
#   'display_phone': '(347) 627-5151',
#   'distance': 4908.4399539324395},
#  {'id': 'dqvNBLqqwgA3iZfRn-Kb6w',
#   'alias': 'the-green-place-nigeria-restaurant-brooklyn',
#   'name': 'The Green Place Nigeria Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lc6BOQjQH0km11_Rn6kHDw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-green-place-nigeria-restaurant-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 30,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.677021, 'longitude': -73.911163},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '180 Rockaway Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11233',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['180 Rockaway Ave', 'Brooklyn, NY 11233']},
#   'phone': '+13477852738',
#   'display_phone': '(347) 785-2738',
#   'distance': 3634.22075830529},
#  {'id': '_sipbeIM-EtR4cIzleEUhg',
#   'alias': 'cafe-rue-dix-brooklyn',
#   'name': 'Cafe Rue Dix',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PdETQUixQGCe54eXuv3iMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cafe-rue-dix-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 366,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'senegalese', 'title': 'Senegalese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6740232907878,
#    'longitude': -73.9538387930572},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1451 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1451 Bedford Ave', 'Brooklyn, NY 11216']},
#   'phone': '+19292342543',
#   'display_phone': '(929) 234-2543',
#   'distance': 2703.6373554528677},
#  {'id': 'cWzdIJhEDZIjSGDpYGWy3Q',
#   'alias': 'buka-new-york-brooklyn',
#   'name': 'Buka New York',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IBO_rn4OqQwLfjyJCsSEcQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buka-new-york-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 253,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'african', 'title': 'African'},
#    {'alias': 'halal', 'title': 'Halal'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.68242, 'longitude': -73.96301},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '946 Fulton St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['946 Fulton St', 'Brooklyn, NY 11238']},
#   'phone': '+13477630619',
#   'display_phone': '(347) 763-0619',
#   'distance': 3884.018898308043},
#  {'id': 'Rb0wYM83GifC-P1Rqd23Bg',
#   'alias': 'hadja-marley-brooklyn',
#   'name': 'Hadja Marley',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GU0X9nr7DBZPThLqGzDyAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hadja-marley-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 7,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.68147, 'longitude': -73.95611},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1139 Fulton St',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1139 Fulton St', 'Brooklyn, NY 11238']},
#   'phone': '+17186367422',
#   'display_phone': '(718) 636-7422',
#   'distance': 3532.876270195536},
#  {'id': 'TeOmHHAIMgK4X7BnvA_BmQ',
#   'alias': 'adebola-african-restaurant-woodbridge-township-2',
#   'name': 'Adebola African Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/roZPq28jU46mLMz1vRxIIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/adebola-african-restaurant-woodbridge-township-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 1,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.55499, 'longitude': -74.30152},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '197 Woodbridge Center Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'Woodbridge Township',
#    'zip_code': '07095',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['197 Woodbridge Center Dr',
#     'Woodbridge Township, NJ 07095']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 32145.33845656266},
#  {'id': '4wyPdXX96e0akxvCp268iw',
#   'alias': 'accra-restaurant-new-york',
#   'name': 'Accra Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ffrwe76XkIl-lehuQ-Bvcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/accra-restaurant-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 129,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8079504, 'longitude': -73.9490877},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2065 Adam Clayton Powell Jr Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2065 Adam Clayton Powell Jr Blvd',
#     'New York, NY 10027']},
#   'phone': '+12129327739',
#   'display_phone': '(212) 932-7739',
#   'distance': 17323.55977177803},
#  {'id': 'GjAHO7PA-3Sxg1lkGza4sQ',
#   'alias': 'b-and-b-restaurant-corporation-new-york',
#   'name': 'B&B Restaurant Corporation',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1K16MSCu2unC9HVUqnhDBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/b-and-b-restaurant-corporation-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 147,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7459112, 'longitude': -73.9936086},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '165 West 26th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['165 West 26th St', 'New York, NY 10001']},
#   'phone': '+16464298174',
#   'display_phone': '(646) 429-8174',
#   'distance': 11366.289311741328},
#  {'id': 'lAwfazjM5ot64O4A6EAjjQ',
#   'alias': 'le-succulent-brooklyn-2',
#   'name': 'Le Succulent',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4StjLv6AF0ASwJnPJFh_iQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-succulent-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 89,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.67356, 'longitude': -73.98247},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '291 5th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['291 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+13472278282',
#   'display_phone': '(347) 227-8282',
#   'distance': 4322.981625564775},
#  {'id': 'ibxhUQF1m70ymB9lMFG5og',
#   'alias': 'bati-brooklyn-2',
#   'name': 'Bati',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MnghD_waFAxqH9x04019mQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bati-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 222,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6865076, 'longitude': -73.9746607},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '747 Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['747 Fulton St', 'Brooklyn, NY 11217']},
#   'phone': '+17187979696',
#   'display_phone': '(718) 797-9696',
#   'distance': 4844.406635045685},
#  {'id': 'lXPQ5iNQjEPxX86D8YLV-w',
#   'alias': 'amarachi-brooklyn-2',
#   'name': 'Amarachi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V75vInDaQVfO8Iu2W6HIMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amarachi-brooklyn-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 371,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.69803, 'longitude': -73.98482},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '189 Bridge St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['189 Bridge St', 'Brooklyn, NY 11201']},
#   'phone': '+17182221010',
#   'display_phone': '(718) 222-1010',
#   'distance': 6352.922776445601},
#  {'id': 'uwj3FOQ0ucGOxk3vBXaBCg',
#   'alias': 'teranga-new-york-2',
#   'name': 'Teranga',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hdirer4OT44hO9NmG8V4Zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/teranga-new-york-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 74,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.796278, 'longitude': -73.949119},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1280 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1280 5th Ave', 'New York, NY 10029']},
#   'phone': '+16466631935',
#   'display_phone': '(646) 663-1935',
#   'distance': 16017.41850672178},
#  {'id': 'pwarWuPn7Aw_il-epzJEgg',
#   'alias': 'awash-ethiopian-restaurant-new-york-3',
#   'name': 'Awash Ethiopian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MTJUXz_vjrh7-qaKIXzyxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/awash-ethiopian-restaurant-new-york-3?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 332,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72658, 'longitude': -73.98682},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '338 E 6th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['338 E 6th St', 'New York, NY 10003']},
#   'phone': '+12129829589',
#   'display_phone': '(212) 982-9589',
#   'distance': 9173.860629261962},
#  {'id': 'kXnTlyTQ9foQ6KOvn7SYbQ',
#   'alias': 'africana-restaurant-jamaica',
#   'name': 'Africana Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7J97ujxHc8WJoFbIA6tZIA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/africana-restaurant-jamaica?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 10,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6948099, 'longitude': -73.80568},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '146-12 Liberty Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Jamaica',
#    'zip_code': '11435',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['146-12 Liberty Ave', 'Jamaica, NY 11435']},
#   'phone': '+17186588501',
#   'display_phone': '(718) 658-8501',
#   'distance': 12220.664784429222},
#  {'id': '10jVTXpBuF17HfeALDF_NQ',
#   'alias': 'monas-cuisine-staten-island',
#   'name': 'Monas Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hLDzFu7bg6BKT-PXRinytA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/monas-cuisine-staten-island?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 8,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'african', 'title': 'African'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.6184136034919,
#    'longitude': -74.0850521349529},
#   'transactions': [],
#   'location': {'address1': '360 Targee St',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['360 Targee St', 'Staten Island, NY 10304']},
#   'phone': '+13478253352',
#   'display_phone': '(347) 825-3352',
#   'distance': 12859.17113506546},
#  {'id': 'qg0pk5UG638g4CRLvbiq7Q',
#   'alias': 'le-baobab-gouygui-2-brooklyn',
#   'name': 'Le Baobab Gouygui 2',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vWgPm5vEvsy9omgbk_zT5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-baobab-gouygui-2-brooklyn?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 30,
#   'categories': [{'alias': 'senegalese', 'title': 'Senegalese'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.68077, 'longitude': -73.95211},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1235 Fulton St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1235 Fulton St', 'Brooklyn, NY 11216']},
#   'phone': '+17184844866',
#   'display_phone': '(718) 484-4866',
#   'distance': 3330.2240312398685},
#  {'id': '2tTUnW5filzR3YG-G7rZ0w',
#   'alias': 'benyam-cuisine-new-york',
#   'name': 'Benyam Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B1knNZx_nR5aG1scxAUdZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/benyam-cuisine-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 127,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.82522, 'longitude': -73.94058},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2795 Frederick Douglas Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10039',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2795 Frederick Douglas Blvd', 'New York, NY 10039']},
#   'phone': '+12125107353',
#   'display_phone': '(212) 510-7353',
#   'distance': 19222.462927128287},
#  {'id': 'RC58AacE9s8VMMCz0boE4A',
#   'alias': 'berber-street-food-new-york-2',
#   'name': 'Berber Street Food',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3nEC_E4E3ICRRgSSaiJu4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/berber-street-food-new-york-2?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 47,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7302376195336,
#    'longitude': -74.0033399462744},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '35 Carmine St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35 Carmine St', 'New York, NY 10014']},
#   'phone': '+16468700495',
#   'display_phone': '(646) 870-0495',
#   'distance': 10205.021486575273},
#  {'id': 'C2E1E0o-ssSrf_dokwxTXg',
#   'alias': 'massawa-new-york',
#   'name': 'Massawa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xfrp9C-QkcKfBrUoBbxbwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/massawa-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 297,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'african', 'title': 'African'},
#    {'alias': 'eritrean', 'title': 'Eritrean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8099, 'longitude': -73.95856},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1239 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1239 Amsterdam Ave', 'New York, NY 10027']},
#   'phone': '+12126630505',
#   'display_phone': '(212) 663-0505',
#   'distance': 17582.909342154006},
#  {'id': 'sfF432UjmaMdxBQDigUENw',
#   'alias': 'olaides-kitchen-parlin',
#   'name': "Olaide's Kitchen",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uHn8Z5EqQBslc3BPjsMrLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olaides-kitchen-parlin?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 31,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.4545282409871,
#    'longitude': -74.2946314679703},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '499 Ernston Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Parlin',
#    'zip_code': '08859',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['499 Ernston Rd', 'Parlin, NJ 08859']},
#   'phone': '+17329528880',
#   'display_phone': '(732) 952-8880',
#   'distance': 37211.18231292543},
#  {'id': 'r271Tv2uqJtIcghCFRa8BQ',
#   'alias': 'haile-bistro-new-york',
#   'name': 'Haile Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dkqvQWWa6moYhJvg0BwNeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/haile-bistro-new-york?adjust_creative=JpdKfokHU6gE_qqoxecpzg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JpdKfokHU6gE_qqoxecpzg',
#   'review_count': 219,
#   'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72783, 'longitude': -73.97951},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '182 Ave B',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['182 Ave B', 'New York, NY 10009']},
#   'phone': '+12126738949',
#   'display_phone': '(212) 673-8949',
#   'distance': 9046.199724119593}]

# %%
# explore which objects in the dataframe we need
df_african_food = pd.DataFrame(african_food['businesses'])

# %%
# let's turn the things we need into a pandas dataframe

df_african_food
# Out:
#                         id                                             alias  \
# 0   roT-M9epcHDOGjYgGmWpoA                          ras-plant-based-brooklyn
# 1   NPmqKZzKxwEXCZQZL7viHA                          ghenet-brooklyn-brooklyn
# 2   ECk9dN7IVQvueTCoGO6gCA                       akwaaba-restaurant-brooklyn
# 3   Bo1eW6NCzOMuxIyu6CzutQ                          brooklyn-suya-brooklyn-2
# 4   FdB6KDTEmX8HvomPwySAHg                        joloff-restaurant-brooklyn
# 5   l4fwf8VwAokv3MWT45Ab7g                               bunna-cafe-brooklyn
# 6   YJ05uT-i4-pTUB_y1an6zw                         awash-brooklyn-brooklyn-5
# 7   r_QEUVdoo8dsKR9fK31w3w                        paradis-des-gouts-brooklyn
# 8   Ra7TDn3poDX1RGMKMKTcBA                          hills-kitchen-brooklyn-2
# 9   wSr-7T0yep69hlqCGFuTSA                             festac-grill-brooklyn
# 10  dqvNBLqqwgA3iZfRn-Kb6w       the-green-place-nigeria-restaurant-brooklyn
# 11  _sipbeIM-EtR4cIzleEUhg                             cafe-rue-dix-brooklyn
# 12  cWzdIJhEDZIjSGDpYGWy3Q                            buka-new-york-brooklyn
# 13  Rb0wYM83GifC-P1Rqd23Bg                             hadja-marley-brooklyn
# 14  TeOmHHAIMgK4X7BnvA_BmQ  adebola-african-restaurant-woodbridge-township-2
# 15  4wyPdXX96e0akxvCp268iw                         accra-restaurant-new-york
# 16  GjAHO7PA-3Sxg1lkGza4sQ           b-and-b-restaurant-corporation-new-york
# 17  lAwfazjM5ot64O4A6EAjjQ                           le-succulent-brooklyn-2
# 18  ibxhUQF1m70ymB9lMFG5og                                   bati-brooklyn-2
# 19  lXPQ5iNQjEPxX86D8YLV-w                               amarachi-brooklyn-2
# 20  uwj3FOQ0ucGOxk3vBXaBCg                                teranga-new-york-2
# 21  pwarWuPn7Aw_il-epzJEgg             awash-ethiopian-restaurant-new-york-3
# 22  kXnTlyTQ9foQ6KOvn7SYbQ                       africana-restaurant-jamaica
# 23  10jVTXpBuF17HfeALDF_NQ                       monas-cuisine-staten-island
# 24  qg0pk5UG638g4CRLvbiq7Q                      le-baobab-gouygui-2-brooklyn
# 25  2tTUnW5filzR3YG-G7rZ0w                           benyam-cuisine-new-york
# 26  RC58AacE9s8VMMCz0boE4A                     berber-street-food-new-york-2
# 27  C2E1E0o-ssSrf_dokwxTXg                                  massawa-new-york
# 28  sfF432UjmaMdxBQDigUENw                            olaides-kitchen-parlin
# 29  r271Tv2uqJtIcghCFRa8BQ                             haile-bistro-new-york
#
#                                   name  \
# 0                      Ras Plant Based
# 1                      Ghenet Brooklyn
# 2                   AKWAABA RESTAURANT
# 3                        Brooklyn Suya
# 4                    Joloff Restaurant
# 5                           Bunna Cafe
# 6                       Awash Brooklyn
# 7                    Paradis Des Gouts
# 8                        Hills Kitchen
# 9                         Festac Grill
# 10  The Green Place Nigeria Restaurant
# 11                        Cafe Rue Dix
# 12                       Buka New York
# 13                        Hadja Marley
# 14          Adebola African Restaurant
# 15                    Accra Restaurant
# 16          B&B Restaurant Corporation
# 17                        Le Succulent
# 18                                Bati
# 19                            Amarachi
# 20                             Teranga
# 21          Awash Ethiopian Restaurant
# 22                 Africana Restaurant
# 23                       Monas Cuisine
# 24                 Le Baobab Gouygui 2
# 25                      Benyam Cuisine
# 26                  Berber Street Food
# 27                             Massawa
# 28                    Olaide's Kitchen
# 29                        Haile Bistro
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/MjF2oe...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/vKP2se...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/U0cqXb...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/MK7bCt...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/n9NXWl...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/jGKIcC...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/e_16iI...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/AD-VB6...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/sEbUu_...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/p0x8tb...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/Lc6BOQ...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/PdETQU...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/IBO_rn...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/GU0X9n...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/roZPq2...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/ffrwe7...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/1K16MS...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/4StjLv...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/MnghD_...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/V75vIn...      False
# 20  https://s3-media2.fl.yelpcdn.com/bphoto/hdirer...      False
# 21  https://s3-media2.fl.yelpcdn.com/bphoto/MTJUXz...      False
# 22  https://s3-media2.fl.yelpcdn.com/bphoto/7J97uj...      False
# 23  https://s3-media4.fl.yelpcdn.com/bphoto/hLDzFu...      False
# 24  https://s3-media2.fl.yelpcdn.com/bphoto/vWgPm5...      False
# 25  https://s3-media3.fl.yelpcdn.com/bphoto/B1knNZ...      False
# 26  https://s3-media4.fl.yelpcdn.com/bphoto/3nEC_E...      False
# 27  https://s3-media3.fl.yelpcdn.com/bphoto/Xfrp9C...      False
# 28  https://s3-media4.fl.yelpcdn.com/bphoto/uHn8Z5...      False
# 29  https://s3-media1.fl.yelpcdn.com/bphoto/dkqvQW...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/ras-plant-based-brook...            71
# 1   https://www.yelp.com/biz/ghenet-brooklyn-brook...           496
# 2   https://www.yelp.com/biz/akwaaba-restaurant-br...            16
# 3   https://www.yelp.com/biz/brooklyn-suya-brookly...            65
# 4   https://www.yelp.com/biz/joloff-restaurant-bro...           191
# 5   https://www.yelp.com/biz/bunna-cafe-brooklyn?a...           629
# 6   https://www.yelp.com/biz/awash-brooklyn-brookl...           190
# 7   https://www.yelp.com/biz/paradis-des-gouts-bro...            53
# 8   https://www.yelp.com/biz/hills-kitchen-brookly...            22
# 9   https://www.yelp.com/biz/festac-grill-brooklyn...            24
# 10  https://www.yelp.com/biz/the-green-place-niger...            30
# 11  https://www.yelp.com/biz/cafe-rue-dix-brooklyn...           366
# 12  https://www.yelp.com/biz/buka-new-york-brookly...           253
# 13  https://www.yelp.com/biz/hadja-marley-brooklyn...             7
# 14  https://www.yelp.com/biz/adebola-african-resta...             1
# 15  https://www.yelp.com/biz/accra-restaurant-new-...           129
# 16  https://www.yelp.com/biz/b-and-b-restaurant-co...           147
# 17  https://www.yelp.com/biz/le-succulent-brooklyn...            89
# 18  https://www.yelp.com/biz/bati-brooklyn-2?adjus...           222
# 19  https://www.yelp.com/biz/amarachi-brooklyn-2?a...           371
# 20  https://www.yelp.com/biz/teranga-new-york-2?ad...            74
# 21  https://www.yelp.com/biz/awash-ethiopian-resta...           332
# 22  https://www.yelp.com/biz/africana-restaurant-j...            10
# 23  https://www.yelp.com/biz/monas-cuisine-staten-...             8
# 24  https://www.yelp.com/biz/le-baobab-gouygui-2-b...            30
# 25  https://www.yelp.com/biz/benyam-cuisine-new-yo...           127
# 26  https://www.yelp.com/biz/berber-street-food-ne...            47
# 27  https://www.yelp.com/biz/massawa-new-york?adju...           297
# 28  https://www.yelp.com/biz/olaides-kitchen-parli...            31
# 29  https://www.yelp.com/biz/haile-bistro-new-york...           219
#
#                                            categories  rating  \
# 0   [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     5.0
# 1   [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.0
# 2          [{'alias': 'african', 'title': 'African'}]     4.5
# 3   [{'alias': 'african', 'title': 'African'}, {'a...     4.5
# 4   [{'alias': 'senegalese', 'title': 'Senegalese'...     4.0
# 5   [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.5
# 6   [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.0
# 7   [{'alias': 'african', 'title': 'African'}, {'a...     4.5
# 8   [{'alias': 'african', 'title': 'African'}, {'a...     4.0
# 9          [{'alias': 'african', 'title': 'African'}]     4.0
# 10         [{'alias': 'african', 'title': 'African'}]     4.0
# 11  [{'alias': 'french', 'title': 'French'}, {'ali...     4.0
# 12  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     3.0
# 13         [{'alias': 'african', 'title': 'African'}]     4.0
# 14         [{'alias': 'african', 'title': 'African'}]     4.0
# 15  [{'alias': 'african', 'title': 'African'}, {'a...     4.0
# 16  [{'alias': 'african', 'title': 'African'}, {'a...     4.5
# 17  [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 18     [{'alias': 'ethiopian', 'title': 'Ethiopian'}]     3.5
# 19  [{'alias': 'tradamerican', 'title': 'American ...     3.5
# 20         [{'alias': 'african', 'title': 'African'}]     4.5
# 21  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.0
# 22         [{'alias': 'african', 'title': 'African'}]     4.0
# 23  [{'alias': 'caribbean', 'title': 'Caribbean'},...     5.0
# 24  [{'alias': 'senegalese', 'title': 'Senegalese'...     3.5
# 25     [{'alias': 'ethiopian', 'title': 'Ethiopian'}]     5.0
# 26         [{'alias': 'african', 'title': 'African'}]     4.5
# 27  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.0
# 28         [{'alias': 'african', 'title': 'African'}]     4.5
# 29  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.5
#
#                                           coordinates        transactions  \
# 0     {'latitude': 40.67341, 'longitude': -73.956712}  [delivery, pickup]
# 1    {'latitude': 40.6791399, 'longitude': -73.98153}  [delivery, pickup]
# 2    {'latitude': 40.655952, 'longitude': -73.953308}                  []
# 3      {'latitude': 40.67402, 'longitude': -73.95661}  [delivery, pickup]
# 4       {'latitude': 40.6841, 'longitude': -73.95422}  [delivery, pickup]
# 5    {'latitude': 40.705042, 'longitude': -73.928078}  [delivery, pickup]
# 6       {'latitude': 40.6858, 'longitude': -73.99441}  [delivery, pickup]
# 7      {'latitude': 40.69333, 'longitude': -73.92931}  [delivery, pickup]
# 8      {'latitude': 40.70253, 'longitude': -73.92513}  [delivery, pickup]
# 9   {'latitude': 40.6757317, 'longitude': -73.8899...  [delivery, pickup]
# 10   {'latitude': 40.677021, 'longitude': -73.911163}          [delivery]
# 11  {'latitude': 40.6740232907878, 'longitude': -7...  [delivery, pickup]
# 12     {'latitude': 40.68242, 'longitude': -73.96301}  [delivery, pickup]
# 13     {'latitude': 40.68147, 'longitude': -73.95611}                  []
# 14     {'latitude': 40.55499, 'longitude': -74.30152}  [delivery, pickup]
# 15  {'latitude': 40.8079504, 'longitude': -73.9490...  [delivery, pickup]
# 16  {'latitude': 40.7459112, 'longitude': -73.9936...  [delivery, pickup]
# 17     {'latitude': 40.67356, 'longitude': -73.98247}  [delivery, pickup]
# 18  {'latitude': 40.6865076, 'longitude': -73.9746...  [delivery, pickup]
# 19     {'latitude': 40.69803, 'longitude': -73.98482}  [delivery, pickup]
# 20   {'latitude': 40.796278, 'longitude': -73.949119}  [delivery, pickup]
# 21     {'latitude': 40.72658, 'longitude': -73.98682}  [delivery, pickup]
# 22   {'latitude': 40.6948099, 'longitude': -73.80568}  [delivery, pickup]
# 23  {'latitude': 40.6184136034919, 'longitude': -7...                  []
# 24     {'latitude': 40.68077, 'longitude': -73.95211}  [delivery, pickup]
# 25     {'latitude': 40.82522, 'longitude': -73.94058}          [delivery]
# 26  {'latitude': 40.7302376195336, 'longitude': -7...  [delivery, pickup]
# 27      {'latitude': 40.8099, 'longitude': -73.95856}  [delivery, pickup]
# 28  {'latitude': 40.4545282409871, 'longitude': -7...          [delivery]
# 29     {'latitude': 40.72783, 'longitude': -73.97951}  [delivery, pickup]
#
#                                              location         phone  \
# 0   {'address1': '739 Franklin Ave', 'address2': '...  +17186226220
# 1   {'address1': '348 Douglass St', 'address2': ''...  +17182304475
# 2   {'address1': '604 Parkside Ave', 'address2': '...  +13479852588
# 3   {'address1': '717 Franklin Ave', 'address2': N...  +17185130122
# 4   {'address1': '1168 Bedford Ave', 'address2': '...  +17182300523
# 5   {'address1': '1084 Flushing Ave', 'address2': ...  +13472952227
# 6   {'address1': '242 Court St', 'address2': '', '...  +17182432151
# 7   {'address1': '1136 Broadway', 'address2': '', ...  +17184434584
# 8   {'address1': '252 Knickerbocker Ave', 'address...  +19294808775
# 9   {'address1': '263 Hendrix St', 'address2': '',...  +13476275151
# 10  {'address1': '180 Rockaway Ave', 'address2': N...  +13477852738
# 11  {'address1': '1451 Bedford Ave', 'address2': '...  +19292342543
# 12  {'address1': '946 Fulton St', 'address2': None...  +13477630619
# 13  {'address1': '1139 Fulton St', 'address2': Non...  +17186367422
# 14  {'address1': '197 Woodbridge Center Dr', 'addr...
# 15  {'address1': '2065 Adam Clayton Powell Jr Blvd...  +12129327739
# 16  {'address1': '165 West 26th St', 'address2': '...  +16464298174
# 17  {'address1': '291 5th Ave', 'address2': None, ...  +13472278282
# 18  {'address1': '747 Fulton St', 'address2': '', ...  +17187979696
# 19  {'address1': '189 Bridge St', 'address2': '', ...  +17182221010
# 20  {'address1': '1280 5th Ave', 'address2': '', '...  +16466631935
# 21  {'address1': '338 E 6th St', 'address2': '', '...  +12129829589
# 22  {'address1': '146-12 Liberty Ave', 'address2':...  +17186588501
# 23  {'address1': '360 Targee St', 'address2': None...  +13478253352
# 24  {'address1': '1235 Fulton St', 'address2': Non...  +17184844866
# 25  {'address1': '2795 Frederick Douglas Blvd', 'a...  +12125107353
# 26  {'address1': '35 Carmine St', 'address2': '', ...  +16468700495
# 27  {'address1': '1239 Amsterdam Ave', 'address2':...  +12126630505
# 28  {'address1': '499 Ernston Rd', 'address2': Non...  +17329528880
# 29  {'address1': '182 Ave B', 'address2': None, 'a...  +12126738949
#
#      display_phone      distance price
# 0   (718) 622-6220   2761.009953   NaN
# 1   (718) 230-4475   4640.694290    $$
# 2   (347) 985-2588   1248.948701    $$
# 3   (718) 513-0122   2815.144768    $$
# 4   (718) 230-0523   3755.893399    $$
# 5   (347) 295-2227   5938.015893    $$
# 6   (718) 243-2151   5957.100687    $$
# 7   (718) 443-4584   4645.028871    $$
# 8   (929) 480-8775   5700.697832   NaN
# 9   (347) 627-5151   4908.439954    $$
# 10  (347) 785-2738   3634.220758    $$
# 11  (929) 234-2543   2703.637355    $$
# 12  (347) 763-0619   3884.018898    $$
# 13  (718) 636-7422   3532.876270     $
# 14                  32145.338457   NaN
# 15  (212) 932-7739  17323.559772    $$
# 16  (646) 429-8174  11366.289312     $
# 17  (347) 227-8282   4322.981626   NaN
# 18  (718) 797-9696   4844.406635    $$
# 19  (718) 222-1010   6352.922776    $$
# 20  (646) 663-1935  16017.418507    $$
# 21  (212) 982-9589   9173.860629    $$
# 22  (718) 658-8501  12220.664784    $$
# 23  (347) 825-3352  12859.171135   NaN
# 24  (718) 484-4866   3330.224031    $$
# 25  (212) 510-7353  19222.462927    $$
# 26  (646) 870-0495  10205.021487   NaN
# 27  (212) 663-0505  17582.909342    $$
# 28  (732) 952-8880  37211.182313    $$
# 29  (212) 673-8949   9046.199724    $$

# %%
# you can do some analysis and visualization from here on! 
review_count_df = df_african_food.review_count
review_count_df
# visualize the review count - what's the appropriate plot?
plt.hist(review_count_df)
# Out:
# (array([12.,  4.,  3.,  4.,  2.,  3.,  0.,  1.,  0.,  1.]),
#  array([  1. ,  63.8, 126.6, 189.4, 252.2, 315. , 377.8, 440.6, 503.4,
#         566.2, 629. ]),
#  <a list of 10 Patch objects>)

# %%
#Look into .gitignore
#Look into geopandas , plotlity

# %%
# query the name of the axe throwing place with the highest review
highest_review_df = df_african_food.review_count.max()
highest_review_df
# Out:
# 629

# %%
# migrate the cleaned data into a sql db

df_african_food = pd.DataFrame(df_african_food)
df_african_food.to_csv('african_food.csv')
african_food = pd.read_csv('african_food.csv')


conn = sqlite3.connect('yelp.db')
c = conn.cursor()

# %%
# can you do some other queries using sql/pandas?
coordinates = df_african_food['coordinates']
coordinates
# Out:
# 0       {'latitude': 40.67341, 'longitude': -73.956712}
# 1      {'latitude': 40.6791399, 'longitude': -73.98153}
# 2      {'latitude': 40.655952, 'longitude': -73.953308}
# 3        {'latitude': 40.67402, 'longitude': -73.95661}
# 4         {'latitude': 40.6841, 'longitude': -73.95422}
# 5      {'latitude': 40.705042, 'longitude': -73.928078}
# 6         {'latitude': 40.6858, 'longitude': -73.99441}
# 7        {'latitude': 40.69333, 'longitude': -73.92931}
# 8        {'latitude': 40.70253, 'longitude': -73.92513}
# 9     {'latitude': 40.6757317, 'longitude': -73.8899...
# 10     {'latitude': 40.677021, 'longitude': -73.911163}
# 11    {'latitude': 40.6740232907878, 'longitude': -7...
# 12       {'latitude': 40.68242, 'longitude': -73.96301}
# 13       {'latitude': 40.68147, 'longitude': -73.95611}
# 14       {'latitude': 40.55499, 'longitude': -74.30152}
# 15    {'latitude': 40.8079504, 'longitude': -73.9490...
# 16    {'latitude': 40.7459112, 'longitude': -73.9936...
# 17       {'latitude': 40.67356, 'longitude': -73.98247}
# 18    {'latitude': 40.6865076, 'longitude': -73.9746...
# 19       {'latitude': 40.69803, 'longitude': -73.98482}
# 20     {'latitude': 40.796278, 'longitude': -73.949119}
# 21       {'latitude': 40.72658, 'longitude': -73.98682}
# 22     {'latitude': 40.6948099, 'longitude': -73.80568}
# 23    {'latitude': 40.6184136034919, 'longitude': -7...
# 24       {'latitude': 40.68077, 'longitude': -73.95211}
# 25       {'latitude': 40.82522, 'longitude': -73.94058}
# 26    {'latitude': 40.7302376195336, 'longitude': -7...
# 27        {'latitude': 40.8099, 'longitude': -73.95856}
# 28    {'latitude': 40.4545282409871, 'longitude': -7...
# 29       {'latitude': 40.72783, 'longitude': -73.97951}
# Name: coordinates, dtype: object

# %%
df_african_food['latitude'] = coordinates[0]['latitude']
df_african_food.head()

# Fix this. You accidentally assigned the first latitude to all of them
# Out:
#                        id                        alias                name  \
# 0  roT-M9epcHDOGjYgGmWpoA     ras-plant-based-brooklyn     Ras Plant Based
# 1  NPmqKZzKxwEXCZQZL7viHA     ghenet-brooklyn-brooklyn     Ghenet Brooklyn
# 2  ECk9dN7IVQvueTCoGO6gCA  akwaaba-restaurant-brooklyn  AKWAABA RESTAURANT
# 3  Bo1eW6NCzOMuxIyu6CzutQ     brooklyn-suya-brooklyn-2       Brooklyn Suya
# 4  FdB6KDTEmX8HvomPwySAHg   joloff-restaurant-brooklyn   Joloff Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/MjF2oe...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/vKP2se...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/U0cqXb...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/MK7bCt...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/n9NXWl...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ras-plant-based-brook...            71
# 1  https://www.yelp.com/biz/ghenet-brooklyn-brook...           496
# 2  https://www.yelp.com/biz/akwaaba-restaurant-br...            16
# 3  https://www.yelp.com/biz/brooklyn-suya-brookly...            65
# 4  https://www.yelp.com/biz/joloff-restaurant-bro...           191
#
#                                           categories  rating  \
# 0  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     5.0
# 1  [{'alias': 'ethiopian', 'title': 'Ethiopian'},...     4.0
# 2         [{'alias': 'african', 'title': 'African'}]     4.5
# 3  [{'alias': 'african', 'title': 'African'}, {'a...     4.5
# 4  [{'alias': 'senegalese', 'title': 'Senegalese'...     4.0
#
#                                         coordinates        transactions  \
# 0   {'latitude': 40.67341, 'longitude': -73.956712}  [delivery, pickup]
# 1  {'latitude': 40.6791399, 'longitude': -73.98153}  [delivery, pickup]
# 2  {'latitude': 40.655952, 'longitude': -73.953308}                  []
# 3    {'latitude': 40.67402, 'longitude': -73.95661}  [delivery, pickup]
# 4     {'latitude': 40.6841, 'longitude': -73.95422}  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '739 Franklin Ave', 'address2': '...  +17186226220
# 1  {'address1': '348 Douglass St', 'address2': ''...  +17182304475
# 2  {'address1': '604 Parkside Ave', 'address2': '...  +13479852588
# 3  {'address1': '717 Franklin Ave', 'address2': N...  +17185130122
# 4  {'address1': '1168 Bedford Ave', 'address2': '...  +17182300523
#
#     display_phone     distance price  latitude
# 0  (718) 622-6220  2761.009953   NaN  40.67341
# 1  (718) 230-4475  4640.694290    $$  40.67341
# 2  (347) 985-2588  1248.948701    $$  40.67341
# 3  (718) 513-0122  2815.144768    $$  40.67341
# 4  (718) 230-0523  3755.893399    $$  40.67341

# %% [markdown]
# #### Resources
# - [Getting Data from Reddit API](https://www.storybench.org/how-to-scrape-reddit-with-python/)
# - [Twitch API](https://dev.twitch.tv/docs)

# %%
import geopandas as gpd
from shapely.geometry import Point
# %matplotlib inline

# %%
#!pip install geopandas

# %%
from shapely.geometry import Polygon

# %%
from shapely.geometry import Point, Polygon

# %%
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3

# %%
#!pip install geopy
